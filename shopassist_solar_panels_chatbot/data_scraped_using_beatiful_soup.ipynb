# %% [markdown]
# # Top3 Solar Panels Reccomendation Scraping Project
#
# ## Introduction
# This project involves scraping data about solar panels from a website using BeautifulSoup. The data includes various specifications and features of different solar panels, which will be used to build a recommendation system.
#
# ## Objectives
# - To collect detailed information about solar panels from the web:  'https://www.moglix.com/solar/solar-panels/213110000'.
# - To clean and structure the scraped data for analysis.
# - To store the data in a format suitable for further processing and analysis.
#
# ---

# %% [markdown]
# ### Libraries and Modules
#
# The following Python libraries are used in this project:
#
# - **pandas**: To handle and manipulate the data in tabular form.
# - **requests**: To make HTTP requests to the web pages.
# - **BeautifulSoup**: To parse the HTML content and extract data.
# - **numpy**: For numerical operations and handling arrays.

# %%
# !pip3 install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip3 install beautifulSoup4
# Out:
# Requirement already satisfied: beautifulSoup4 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\downloads\practice_folder\.venv\lib\site-packages (from beautifulSoup4) (2.5)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
}

response = requests.get('https://www.moglix.com/solar/solar-panels/213110000', headers=headers)
print(response.text)
# Out:
#       <!DOCTYPE html><html lang="en"><head>
#     <!--- PWA Related configs & metas -->
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <!-- <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no"> -->
#     <meta name="copyright" content="© 2017 Moglix.com.">
#     <meta name="Author" content="Moglix.com">
#     <meta name="Created By" content="Moglix.com">
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <!-- <meta http-equiv="content-language" content="en" /> -->
#     <meta name="msvalidate.01" content="87CB1389FBF8BFACC48814311296A163">
#     <meta name="viewport" content="user-scalable=no, width=device-width">
#     <meta http-equiv="ScreenOrientation" content="autoRotate:disabled">
#     <meta name="theme-color" content="#d9232d">
#     <meta name="apple-mobile-web-app-status-bar-style" content="#ffffff">
#     <meta name="theme-color" content="#ffffff">
#     <meta name="theme-color" content="#1976d2">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
#     <meta name="theme-color" content="#1976d2">
#     <base href="/">
#     <meta name="environment" content="development">
#
#     <link rel="icon" type="image/vnd.microsoft.icon" href="assets/img/favicon-con.png">
#     <link rel="manifest" href="manifest.webmanifest" crossorigin="use-credentials">
#
#     <!-- INSERT DYNAMIC FONT PRELOAD AFTER SSR BUILD HERE -->
#
#
#
#     <link rel="preload" href="https://cdn.moglix.com/online/prod/desktop/bundles/styles.c15623dfa069881be6b3.css" as="style" onload="this.onload=null;this.rel='stylesheet'">
#     <noscript><link rel="stylesheet" href="https://cdn.moglix.com/online/prod/desktop/bundles/styles.c15623dfa069881be6b3.css"></noscript>
#
#             <!-- INSERT DYNAMIC CSS PRELOAD DURING BUILD HERE -->
#
#     <!-- INSERT DYNAMIC IMAGES PRELOAD DURING SSR SERVE HERE -->
#       <link rel="preload" as="image" href="/assets/img/moglix_logo_red@3x.png">
#         <link rel="preload" as="image" href="assets/img/deliver-location.svg">
#         <link rel="preload" as="image" href="../../../assets/img/vernacular-icon.svg">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/cms/utility/1714474095774-16R82Js-foJcYltuKaV1Wk0w.png">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/assets/img/home_card.webp">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/cms/utility/1714474137688-EBmVzHI5RggN1Q1gi4gKknwl.png">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/assets/img/home_card.webp">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/cms/utility/1714474137688-EBmVzHI5RggN1Q1gi4gKknwl.png">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/assets/img/home_card.webp">
#         <link rel="preload" as="image" href="https://cdn.moglix.com/cms/utility/1714474137688-EBmVzHI5RggN1Q1gi4gKknwl.png">
#
#
#
# <link rel="stylesheet" href="https://cdn.moglix.com/online/prod/desktop/bundles/styles.c15623dfa069881be6b3.css"><style data-ng-transition="ssr-pwa"></style><style data-ng-transition="ssr-pwa">.f-10{font-size:10px}.success-text{color:var(--slimy-green)}.error-txt{color:var(--primary)}.fontBold{font-weight:700}.desktop-container{width:100%;max-width:1500px;margin:0 auto;padding:10px 0 0}.cursor{cursor:pointer!important}footer{font-size:14px}footer.card-30{background:var(--white);padding-bottom:0}footer b{display:block}#footerContainer h1,.other-links{font-size:10px}.other-links{text-align:center}.other-links li{padding:0;display:inline-block}.subscription-content{width:100%;padding:0 3%}.scroll_top{position:fixed;right:10px;opacity:1;bottom:40px;visibility:visible;background:#222;width:30px;height:30px;text-align:center;transition:all .5s ease-in-out;line-height:30px;z-index:33;color:#fff;font-size:16px;border-radius:50%}.scroll_top.opacityzero{opacity:0;visibility:hidden;z-index:-1;transition:all .5s ease-in-out}.block{display:block}.open .screen-view{top:0!important}.desktop-wrapper{margin:0 auto;width:100%}</style><style data-ng-transition="ssr-pwa">.f-10[data-_ngcontent-sc52]{font-size:10px}.success-text[data-_ngcontent-sc52]{color:var(--slimy-green)}.error-txt[data-_ngcontent-sc52]{color:var(--primary)}.fontBold[data-_ngcontent-sc52]{font-weight:700}.desktop-container[data-_ngcontent-sc52]{width:100%;max-width:1500px;margin:0 auto;padding:10px 0 0}.cursor[data-_ngcontent-sc52]{cursor:pointer!important}header.inner-pages[data-_ngcontent-sc52]{box-shadow:0 2px 15px rgba(0,0,0,.15);position:fixed;top:0;z-index:30;left:0;right:0}header[data-_ngcontent-sc52]   .main-header[data-_ngcontent-sc52]{background:var(--white)}header.lowzindex[data-_ngcontent-sc52]{z-index:2}.varientzindex[data-_ngcontent-sc52]{z-index:2!important}</style><style data-ng-transition="ssr-pwa">.bottom-options[data-_ngcontent-sc54]   .content-box[data-_ngcontent-sc54]{transition:all .25s ease-in-out}.bottom-options[data-_ngcontent-sc54]   .content-box[data-_ngcontent-sc54]   .container-head-sec[data-_ngcontent-sc54]:after{content:"";clear:both;width:100%;float:none;height:0;margin:0;padding:0;display:block}.bottom-options[data-_ngcontent-sc54]   .content-box[data-_ngcontent-sc54]   .container-head-sec[data-_ngcontent-sc54]   i[data-_ngcontent-sc54]{float:right;font-size:17px}.bottom-options[data-_ngcontent-sc54]   .content-box[data-_ngcontent-sc54]   .container-head-sec[data-_ngcontent-sc54]   .txt[data-_ngcontent-sc54]{float:left;width:calc(100% - 20px)}#bottom-options-rfq.open[data-_ngcontent-sc54]   .content-box.mintCreamBg[data-_ngcontent-sc54]{-ms-overflow-style:none;scrollbar-width:none}#bottom-options-rfq.open[data-_ngcontent-sc54]   .content-box.mintCreamBg[data-_ngcontent-sc54]::-webkit-scrollbar{display:none}.f-10[data-_ngcontent-sc54]{font-size:10px}.success-text[data-_ngcontent-sc54]{color:var(--slimy-green)}.error-txt[data-_ngcontent-sc54]{color:var(--primary)}.fontBold[data-_ngcontent-sc54]{font-weight:700}.desktop-container[data-_ngcontent-sc54]{width:100%;max-width:1500px;margin:0 auto;padding:10px 0 0}.cursor[data-_ngcontent-sc54]{cursor:pointer!important}#bottom-options-rfq[data-_ngcontent-sc54]   .overlay[data-_ngcontent-sc54]{z-index:106}#bottom-options-rfq.open[data-_ngcontent-sc54]   .content-box[data-_ngcontent-sc54]{padding-bottom:0!important;max-height:80%!important;z-index:107}#bottom-options-rfq.open[data-_ngcontent-sc54]   .content-box.mintCreamBg[data-_ngcontent-sc54]{max-height:54%!important}.bottom-options[data-_ngcontent-sc54]   .overlay-bg[data-_ngcontent-sc54]{z-index:13;top:120%}.bottom-options[data-_ngcontent-sc54]   .overlay[data-_ngcontent-sc54]{z-index:10}.bottom-options[data-_ngcontent-sc54]   .content-box[data-_ngcontent-sc54]{position:fixed;bottom:-100%;left:0;background:var(--white);z-index:14;width:100%;max-height:70%;overflow:auto;z-index:108;border-radius:20px 20px 0 0}.bottom-options[data-_ngcontent-sc54]   .co ...
#
# <body id="body">
#     <app-root _nghost-sc16="" ng-version="11.0.1"><router-outlet data-_ngcontent-sc16=""></router-outlet><app-pages><div class="desktop-wrapper"><header-nav class="show inner_head" _nghost-sc52=""><header data-_ngcontent-sc52="" class="inner-pages inner-pages-for-listing"><div data-_ngcontent-sc52="" class="main-header"><!----><!----><home-expanded-header data-_ngcontent-sc52="" _nghost-sc48=""><login-popup data-_ngcontent-sc48=""><!----></login-popup><div data-_ngcontent-sc48="" class="desktop-home-header"><div data-_ngcontent-sc48="" class="pwa-row desktop-inner-section"><div data-_ngcontent-sc48="" class="hamburg-logo"><img data-_ngcontent-sc48="" alt="logo-2x" src="/assets/img/moglix_logo_red@3x.png" class="logo-2x" tabindex="0"><div data-_ngcontent-sc48="" class="hamburg-menu-container"><i data-_ngcontent-sc48="" class="icon-menu menu-header"></i><!----></div><!----></div><div data-_ngcontent-sc48="" class="search-sec second-search-menu"><form data-_ngcontent-sc48="" novalidate="" class="ng-untouched ng-pristine ng-invalid"><div data-_ngcontent-sc48="" class="search_bar"><input data-_ngcontent-sc48="" formcontrolname="searchTerm" type="text" autocomplete="off" placeholder="Search Product, Category, Brand..." id="search-input" class="search_bar-input ng-untouched ng-pristine ng-invalid" value=""><div data-_ngcontent-sc48="" type="submit" class="input-group"><i data-_ngcontent-sc48="" class="icon-search"></i></div></div></form><div data-_ngcontent-sc48="" class="search-popup-container"><!----></div></div><div data-_ngcontent-sc48="" class="right-container"><div data-_ngcontent-sc48="" class="user-profile-container"><div data-_ngcontent-sc48="" class="user-name profile-item"><div data-_ngcontent-sc48="" class="user-name"><i data-_ngcontent-sc48="" class="icon-profile user-icon"></i><p data-_ngcontent-sc48="" class="item-name">Login Now</p><!----></div></div><!----></div><div data-_ngcontent-sc48="" class="ml-25"><div data-_ngcontent-sc48="" class="track-order right-item"><img data-_ngcontent-sc48="" src="assets/img/deliver-location.svg" alt="track order"><a data-_ngcontent-sc48="" class="item-name">Track Order</a></div></div><div data-_ngcontent-sc48="" class="ml-25"><div data-_ngcontent-sc48="" class="cart-item right-item cursor-pointer"><a data-_ngcontent-sc48="" class="icon-cart1"><!----></a><p data-_ngcontent-sc48="" class="item-name">Cart</p></div></div><div data-_ngcontent-sc48="" class="more-option-container"><div data-_ngcontent-sc48="" class="cart-item right-item more-options"><a data-_ngcontent-sc48="" class="icon-dot"></a></div><!----></div><!----></div></div></div><!----></home-expanded-header><!----><!----></div></header><!----><!----><!----><!----><!----><!----></header-nav><div class="desktop-body nonhomepage"><router-outlet></router-outlet><data-category _nghost-sc155="" class="translateCategory"><div data-_ngcontent-sc155="" class="plp-container-header-adjust"><breadcrumb-nav data-_ngcontent-sc155="" _nghost-sc90=""><div data-_ngcontent-sc90="" class="bread-crumb"><ul data-_ngcontent-sc90="" class="bread-head no-margin"><li data-_ngcontent-sc90="" class="f-size-12" tabindex="0">Home </li><li data-_ngcontent-sc90="" class="item f-size-12"><a data-_ngcontent-sc90="" class="" href="https://www.moglix.com/solar/213000000">Solar</a></li><li data-_ngcontent-sc90="" class="item f-size-12"><a data-_ngcontent-sc90="" class="last" href="https://www.moglix.com/solar/solar-panels/213110000">Solar Panels</a></li><!----></ul></div><!----><!----></breadcrumb-nav><div data-_ngcontent-sc155="" class="visibility"><div data-_ngcontent-sc155="" class="row splnewpage visibility"><div data-_ngcontent-sc155="" class="container-fluid safetyshoebannersrow"><cat-static data-_ngcontent-sc155="" _nghost-sc146=""><!----></cat-static><!----><shopby-brand data-_ngcontent-sc155=""><!----></shopby-brand><cat-bestseller data-_ngcontent-sc155=""><!----></cat-bestseller><div data-_ngcontent-sc155="" class="container-fluid safetyshshopbytype">< ...
#     <div id="alert-box"></div>
#     <!-- Adobe Tag Manager -->
#     <script defer="true">
#         dataLayer = [];
#         // if (navigator && navigator.userAgent.indexOf("Googlebot") === -1) {
#         //     var gtmKey = "GTM-PMPXQQ"; //PROD Key
#         //     (function (w, d, s, l, i) {
#         //         w[l] = w[l] || [];
#         //         w[l].push({
#         //             'gtm.start': new Date().getTime(),
#         //             event: 'gtm.js'
#         //         });
#         //         var f = d.getElementsByTagName(s)[0],
#         //             j = d.createElement(s),
#         //             dl = l != 'dataLayer' ? '&l=' + l : '';
#         //         j.defer = true;
#         //         j.src =
#         //             'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         //         setTimeout(() => {
#         //             f.parentNode.insertBefore(j, f)
#         //         }, 0);
#         //     })(window, document, 'script', 'dataLayer', gtmKey);
#         // }
#         digitalData = {};
#         digitalData.event = [];
#     </script>
#     <script defer="" src="//assets.adobedtm.com/055f91edd8ef/2cc21fe6ff8d/launch-fd00645b6c3b.min.js"></script>
#     <!-- <script defer src="https://www.google-analytics.com/analytics.js" ></script> -->
#     <!-- Adobe Tag Manager -->
#     <noscript>Please enable JavaScript to continue using this application.</noscript>
# <script src="https://cdn.moglix.com/online/prod/desktop/bundles/runtime-es2015.b46ea56d54c811291850.js" type="module"></script><script src="https://cdn.moglix.com/online/prod/desktop/bundles/runtime-es5.b46ea56d54c811291850.js" nomodule="" defer=""></script><script src="https://cdn.moglix.com/online/prod/desktop/bundles/polyfills-es5.766759486ac177d6861a.js" nomodule="" defer=""></script><script src="https://cdn.moglix.com/online/prod/desktop/bundles/polyfills-es2015.38086919d277e34f3d5d.js" type="module"></script><script src="https://cdn.moglix.com/online/prod/desktop/bundles/main-es2015.b4cc59cdf02063ca151c.js" type="module"></script><script src="https://cdn.moglix.com/online/prod/desktop/bundles/main-es5.b4cc59cdf02063ca151c.js" nomodule="" defer=""></script>
#
#
#         <script id="ssr-pwa-state" type="application/json">{&q;get_related-213110000&q;:{&q;categoryDetails&q;:{&q;categoryId&q;:&q;213110000&q;,&q;categoryName&q;:&q;Solar Panels&q;,&q;taxonomy&q;:&q;213000000/213110000&q;,&q;categoryLink&q;:&q;solar/solar-panels/213110000&q;,&q;canonicalURL&q;:&q;solar/solar-panels/213110000&q;,&q;childList&q;:[],&q;mainImageLink&q;:&q;c/I/D/2/d/MINID21RIZK54-medium.jpg&q;,&q;mainImageAltTag&q;:&q;Solar Panels&q;,&q;desc&q;:&q;&l;h2&g;&l;strong&g;Solar Panels: A Brighter, Greener Future for the Planet&l;/strong&g;&l;/h2&g;&l;p&g;Solar panels convert solar energy into a source of sustainable, renewable energy, and turn it into electricity, which is then utilized to power electrical loads. Multiple individual solar cells make up solar panels, and each solar cell is made of layers of silicon, phosphorus (which generates the negative charge), and boron (which provides the positive charge). Solar panels provide power for various uses, a highly practical method. Off-grid living is the most cost-effective choice. Solar power systems are ideal for rural homes and cottages. A solar panel system may be less expensive and capable of producing electricity for up to three decades, depending on maintenance.&l;/p&g;&l;p&g;&a;nbsp;&l;/p&g;&l;p&g;Solar panels are an excellent way of absorbing solar energy and freeing yourself from electricity bills. But before you start planning your solar power system, you&s;ll need to know a few things, such as how many solar panels you&s;ll need. What kinds of solar panels and prices are available in the online market? How can I determine the best company for my solar panel installation?&l;/p&g;&l;p&g;&a;nbsp;&l;/p&g;&l;h2&g;&l;strong&g;Types of Solar Panels Available in the Market&l;/strong&g;&l;/h2&g;&l;p&g;&l;strong&g;Monocrystalline Solar Panels -&l;/strong&g; A monocrystalline solar panel is the most advanced while being the oldest form. In this situation, monocrystalline solar cells are used in the discussions. They are built of pure silicon and have 40 monocrystalline cells in them. Because of how sunlight and pure silicon interact, monocrystalline cells look black. However, customers have several color options when it comes to back sheets and frames.&l;/p&g;&l;p&g;&a;nbsp;&l;/p&g;&l;p&g;&l;strong&g;Polycrystalline Solar Panels -&l;/strong&g; Polycrystalline panels (also known as multicrystalline panels) comprise many silicon crystals in each PV cell. These are the most common of the three types of solar panels. To manufacture them, silicon crystal fragments are heated and sliced into wafers. Polycrystalline panels have a mosaic-like appearance and are square. Because the panels are comprised of multiple silicon crystals, the surface has a blue tint.&l;/p&g;&l;p&g;&a;nbsp;&l;/p&g;&l;p&g;&l;strong&g;Thin-Film Panels -&l;/strong&g; Thin-film panels are a kind of solar cell from the second generation. Thin-film panels, as the name implies, are nearly 350 times thinner than silicon wafer-based panels. Another distinctive element of thin-film panels is their material composition. A thin-film panel, for example, can be composed of cadmium telluride, amorphous silicon, or Copper Indium Gallium Selenide.&l;/p&g;&l;p&g;&a;nbsp;&l;/p&g;&l;h2&g;&l;strong&g;Factors To Consider Before Selecting Solar Panels&l;/strong&g;&l;/h2&g;&l;p&g;&l;strong&g;Choose the right technology&l;/strong&g; - Solar systems are manufactured in various sizes and performance levels, according to the vendors. Some companies manufacture high-quality, very effective solar power systems capable of supplying the required electricity.&l;/p&g;&l;p&g;&a;nbsp;&l;/p&g;&l;p&g;&l;strong&g;Track your energy consumption -&l;/strong&g; You can measure your energy use with a competent solar installer. The amount of energy you want to produce with your solar system depends on this. You have to decide how many solar panels to install and how much of your energy needs solar energy can satisfy by knowing the average amou ...

# %%
# webpage=requests.get('https://www.zigwheels.com/newcars/electric-cars').text
webpage=requests.get('https://www.moglix.com/solar/solar-panels/213110000').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
# company=soup.find_all('div',class_='product-vertical-grid-card cursor active-hover')
company=soup.find_all('div',class_='product-card-lower-inner')

# %%
len(company)
# Out:
# 40

# %% [markdown]
# ## To find out the brand names

# %%
name = []
for i in company:
    name.append(i.find('div',class_='name').text.strip())

# %%
name
# Out:
# ['Luminous 550W 24V Mono PERC Halfcut Solar Panel',
#  'Waaree Bi-55-540 540W 144 Cells Framed Dual Glass Mono PERC Bifacial Solar Module ...',
#  'Solar Universe 335W 24V Polycrystalline Solar Panel, SUI-335',
#  'Waaree 540W 144 Cells Monocrystalline PERC Solar Panel, WSMD-540 ...',
#  'Waaree 535Wp 144 Cells Framed Dual Glass Mono PERC Bifacial Solar Module, Bi-55-535 ...',
#  'Luminous LUM 12170 170W Polycrystalline Solar Panel',
#  'Luminous LUM 12170 170W Polycrystalline Solar Panel (Pack of 2) ...',
#  'Solar Universe India 180W 12V Monocrystalline Solar Panel',
#  'UTL 165W 12V Polycrystalline Solar PV Panel',
#  'SUI Solar Panel 10w 12v',
#  'Solar Universe India 425W Bifacial Monocrystalline Solar Panel (Pack of 2) ...',
#  'Solar Universe India 20W Solar Panel',
#  'SUI Solar Silicon & Aluminium 40 Watt Panel (Blue)',
#  'Solar Universe 400W 24V Monocrystalline Solar Panel, SUI-400',
#  'Solar Universe India 425W Bifacial Monocrystalline Solar Panel ...',
#  'SUI 200W Solar Panel 12V (2 Units)',
#  'Waaree 530W 49.31V 144 Cells Framed Dual Glass Mono PERC Bifacial Solar Module, Bi-55-530 ...',
#  'SUI 20 Watt - 12 Volt Solar Panel for Home Lighting & Small Battery Charging (Black) ...',
#  'Waaree 520W 48.86V 144 Cells Framed Dual Glass Mono PERC Bifacial Solar Module, Bi-55-520 ...',
#  'SUI 75 Watt Solar Panel Poly Crystalline (12 V, White)',
#  'Vikram 450W 24V Mono Perc Half Cut Solar Panel',
#  'Galo Energy 400W 24V Mono PERC Solar Panel, SSGS72P400',
#  'SUI 260W Solar Panel (4 Units) - Solar Power - 24V',
#  'Solar Universe 410W 24V Monocrystalline Solar Panel, SUI-410',
#  'Solar Universe India 200W 24V Polycrystalline Solar Panel',
#  'Solar Universe India 200W 12V Polycrystalline Solar Panel',
#  'Livguard LGV12V180M 180W Mono Perc Solar Panel',
#  'Microtek 165W 12V Multi Crystalline Solar PV Module',
#  'Eastman 320W Polycrystalline Solar PV Module, EPP 320W',
#  'Waaree Bi-55-540 540W 144 Cells Framed Dual Glass Mono PERC Bifacial Solar Module, (Pack of 2) ...',
#  'SUI 5W 6V Poly Crystalline Portable Solar Panel',
#  'Waaree 540W 144 Cells Monocrystalline PERC Solar Panel, WSMD-540, (Pack of 2) ...',
#  'SUI 125W Solar Panel Monocrystalline',
#  'Solar Universe India 265W 24V Monocrystalline Solar Panel (Pack of 2) ...',
#  'Birkan 400W 24V Silver Anodized Aluminium Frame MC4 Monocrystalline Solar Panel, Birkan-400 ...',
#  'Solar Universe India 75W White Polycrystalline Solar Panel',
#  'Solar Universe India 150W Solar Panel',
#  'Solar Universe India 60W Solar Panel',
#  'Solar Universe India 375W Monocrystalline Solar Panel',
#  'Solar Universe 1kW 24V Polycrystalline Solar Panel Set, SUI-335-3 ...']

# %% [markdown]
# ## To find out the prices

# %%
purchase_price = []
for i in company:
    purchase_price.append(i.find('div',class_='prod-selling-price').text.strip())

# %%
purchase_price
# Out:
# ['₹16,409',
#  '₹12,799',
#  '₹10,899',
#  '₹12,699',
#  '₹12,899',
#  '₹5,799',
#  '₹12,639',
#  '₹8,699',
#  '₹6,099',
#  '₹699',
#  '₹36,850',
#  '₹1,330',
#  '₹1,909',
#  '₹15,099',
#  '₹16,500',
#  '₹16,610',
#  '₹12,499',
#  '₹1,390',
#  '₹12,399',
#  '₹3,370',
#  '₹18,400',
#  '₹102,359',
#  '₹41,610',
#  '₹16,919',
#  '₹8,199',
#  '₹8,000',
#  '₹8,000',
#  '₹5,980',
#  '₹39,420',
#  '₹24,399',
#  '₹560',
#  '₹24,000',
#  '₹6,129',
#  '₹25,379',
#  '₹16,950',
#  '₹3,200',
#  '₹6,330',
#  '₹3,090',
#  '₹16,300',
#  '₹33,999']

# %% [markdown]
# ## To find out the discounts

# %%
discount = []
for i in company:
    price_div = i.find('div', class_='price')
    if price_div:
        discount_span = price_div.find('span', class_='prod-discount')
        if discount_span:
            discount.append(discount_span.text.strip())
        else:
            discount.append(None)
    else:
        discount.append(None)

# %%
discount
# Out:
# ['60% OFF',
#  '55% OFF',
#  '31% OFF',
#  '53% OFF',
#  '42% OFF',
#  '61% OFF',
#  '57% OFF',
#  '10% OFF',
#  '36% OFF',
#  '39% OFF',
#  '38% OFF',
#  '34% OFF',
#  '30% OFF',
#  '31% OFF',
#  '45% OFF',
#  '22% OFF',
#  '32% OFF',
#  '35% OFF',
#  '28% OFF',
#  '20% OFF',
#  '8% OFF',
#  '1% OFF',
#  '18% OFF',
#  '32% OFF',
#  '23% OFF',
#  '21% OFF',
#  '20% OFF',
#  '60% OFF',
#  '6% OFF',
#  '57% OFF',
#  '18% OFF',
#  '56% OFF',
#  '22% OFF',
#  '44% OFF',
#  '10% OFF',
#  '31% OFF',
#  '43% OFF',
#  '18% OFF',
#  '19% OFF',
#  '29% OFF']

# %% [markdown]
# ## To find out the ratings

# %%
review = []
for i in company:
    rating_span = i.find('span', class_='avgrating')
    if rating_span:  # Check if the span element was found
        review.append(rating_span.text.strip())
    else:
        review.append('N/A')  # Or handle the absence of the span element as needed

print(review)
# Out:
# ['4.6', '4.0', '4.5', '4.5', '4.6', '4.6', '4.6', '4.4', '4.2', '4.3', '4.3', '3.8', '4.5', '4.4', '4.0', '4.8', '4.6', '4.2', '4.6', '4.2', '4.4', '4.2', '4.0', '4.6', '4.2', '4.3', '4.0', '4.3', '4.0', '4.2', '4.4', '4.6', '4.4', '4.6', '4.3', '4.7', '4.7', '4.3', '4.8', '4.8']

# %%
real_price = []
for i in company:   
    real_price_span = i.find('span', class_='prod-mrp')
    real_price.append(real_price_span.text.strip() if real_price_span else np.nan)

# %%
real_price
# Out:
# ['₹42,000',
#  '₹28,869',
#  '₹16,000',
#  '₹27,279',
#  '₹22,399',
#  '₹15,000',
#  '₹30,000',
#  '₹9,750',
#  '₹9,570',
#  '₹1,155',
#  '₹60,000',
#  '₹2,018',
#  '₹2,730',
#  '₹22,000',
#  '₹30,200',
#  '₹21,525',
#  '₹18,480',
#  '₹2,152',
#  '₹17,360',
#  '₹4,253',
#  '₹20,100',
#  '₹103,425',
#  '₹50,925',
#  '₹25,000',
#  '₹10,750',
#  '₹10,250',
#  '₹10,000',
#  '₹14,990',
#  '₹42,195',
#  '₹57,719',
#  '₹683',
#  '₹54,549',
#  '₹7,875',
#  '₹46,000',
#  '₹19,000',
#  '₹4,650',
#  '₹11,290',
#  '₹3,779',
#  '₹20,250',
#  '₹48,000']

# %% [markdown]
# ## Now we wiil create a solar_panel.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

final = []

for j in range(1, 1000):
    webpage = requests.get('https://www.moglix.com/solar/solar-panels/213110000={}'.format(j)).text
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div', class_='product-card-lower-inner')
    
    name = []
    price = []
    discount = []
    real_price = []
    review = []
    all_links = []

    for i in company:
        try:
            name.append(i.find('div', class_='name').text.strip())
        except:
            name.append(np.nan)

        try:
            price.append(i.find('div', class_='prod-selling-price').text.strip())
        except:
            price.append(np.nan)
        
        try:
            discount_span = i.find('span', class_='prod-discount')
            discount.append(discount_span.text.strip() if discount_span else np.nan)
        except:
            discount.append(np.nan)

        try:
            real_price_span = i.find('span', class_='prod-mrp')
            real_price.append(real_price_span.text.strip() if real_price_span else np.nan)
        except:
            real_price.append(np.nan)
        
        try:
            rating_span = i.find('span', class_='avgrating')
            review.append(rating_span.text.strip() if rating_span else np.nan)
        except:
            review.append(np.nan)

        try:
            discription = i.find('div',class_='name')
            pattern = r'href="([^"]+)"'
            match = re.search(pattern, str(discription))
            if match:
                url = match.group(1)
                all_links.append(url)
            else:
                all_links.append(np.nan)       
        except:
            all_links.append(np.nan)

    # Ensure all lists are of the same length
    max_length = max(len(name), len(price), len(discount), len(real_price), len(review), len(all_links))

    name.extend([np.nan] * (max_length - len(name)))
    price.extend([np.nan] * (max_length - len(price)))
    discount.extend([np.nan] * (max_length - len(discount)))
    real_price.extend([np.nan] * (max_length - len(real_price)))
    review.extend([np.nan] * (max_length - len(review)))
    all_links.extend([np.nan] * (max_length - len(all_links)))


    df = pd.DataFrame({
        'name': name,
        'purchase_price': price,
        'discount': discount,
        'real_price': real_price,
        'rating': review,
        'Page URL': all_links
    })
    
    final.append(df)

final_df = pd.concat(final, ignore_index=True)
print(final_df)
# Out:
#                                                   name purchase_price  \
# 0      Luminous 550W 24V Mono PERC Halfcut Solar Panel        ₹16,409
# 1    Waaree Bi-55-540 540W 144 Cells Framed Dual Gl...        ₹12,799
# 2    Solar Universe 335W 24V Polycrystalline Solar ...        ₹10,899
# 3    Waaree 540W 144 Cells Monocrystalline PERC Sol...        ₹12,699
# 4    Waaree 535Wp 144 Cells Framed Dual Glass Mono ...        ₹12,899
# ..                                                 ...            ...
# 355  Solar Universe India 75W White Polycrystalline...         ₹3,200
# 356              Solar Universe India 150W Solar Panel         ₹6,330
# 357               Solar Universe India 60W Solar Panel         ₹3,090
# 358  Solar Universe India 375W Monocrystalline Sola...        ₹16,300
# 359  Solar Universe 1kW 24V Polycrystalline Solar P...        ₹33,999
#
#     discount real_price rating  \
# 0    60% OFF    ₹42,000    4.6
# 1    55% OFF    ₹28,869    4.0
# 2    31% OFF    ₹16,000    4.5
# 3    53% OFF    ₹27,279    4.5
# 4    42% OFF    ₹22,399    4.6
# ..       ...        ...    ...
# 355  31% OFF     ₹4,650    4.7
# 356  43% OFF    ₹11,290    4.7
# 357  18% OFF     ₹3,779    4.3
# 358  19% OFF    ₹20,250    4.8
# 359  29% OFF    ₹48,000    4.8
#
#                                               Page URL
# 0    https://www.moglix.com/luminous-550w-24v-mono-...
# 1    https://www.moglix.com/waaree-bi-55-540-540w-1...
# 2    https://www.moglix.com/solar-universe-335w-24v...
# 3    https://www.moglix.com/waaree-540w-144-cells-m...
# 4    https://www.moglix.com/waaree-535wp-144-cells-...
# ..                                                 ...
# 355  https://www.moglix.com/solar-universe-india-75...
# 356  https://www.moglix.com/solar-universe-india-15...
# 357  https://www.moglix.com/solar-universe-india-60...
# 358  https://www.moglix.com/solar-universe-india-37...
# 359  https://www.moglix.com/solar-universe-1kw-24v-...
#
# [360 rows x 6 columns]

# %%
final_df.to_csv('solar_panel.csv')
